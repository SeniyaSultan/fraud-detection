# %% [markdown]
# # Model Explainability using SHAP
#
# This notebook uses SHAP (SHapley Additive exPlanations) to interpret the Random Forest model
# for e-commerce fraud detection. The goal is to understand which features drive predictions
# and provide actionable business recommendations.

# %%
# install missing package in the notebook environment
# %pip install shap -q

import pandas as pd
import numpy as np
import shap
import joblib
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("default")
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import joblib

X_test_path = r"C:\Users\jkk\OneDrive\Desktop\fraud-detection\data\processed\X_test.csv"
X_test = pd.read_csv(X_test_path)

X_test.head()
# Out:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0   360572  2015-02-22 00:08:34  2015-03-20 00:52:07              34
# 1   244596  2015-04-16 00:37:20  2015-05-23 20:45:36              18
# 2   113421  2015-06-22 02:43:53  2015-07-17 22:29:58              39
# 3    35236  2015-01-02 23:40:01  2015-01-02 23:40:02              19
# 4   163254  2015-01-11 04:52:17  2015-01-11 04:52:18              10
#
#        device_id source browser sex  age  ip_address  lower_bound_ip_address  \
# 0  FPDCKGEGCNQOS    Ads  Safari   F   31  2487467045            2.487419e+09
# 1  QOSGRNENSTKDE    Ads  Chrome   F   24  1177415539            1.177354e+09
# 2  YCESMLPKLRGDL    Ads  Chrome   F   32  1192301392            1.192296e+09
# 3  VOZBUVAHONAOL    SEO      IE   M   38  3629014908            3.628859e+09
# 4  QXBQQIAHDCNDK    Ads  Chrome   M   27  3621382730            3.607101e+09
#
#    upper_bound_ip_address        country  time_since_signup  hour_of_day  \
# 0            2.487484e+09  United States          2249013.0            0
# 1            1.177420e+09    Puerto Rico          3269296.0           20
# 2            1.192362e+09         Canada          2231165.0           22
# 3            3.629122e+09  United States                1.0           23
# 4            3.623879e+09  United States                1.0            4
#
#    day_of_week  transactions_per_user      ip_int
# 0            4                      1  2487467045
# 1            5                      1  1177415539
# 2            4                      1  1192301392
# 3            4                      1  3629014908
# 4            6                      1  3621382730

# %%
X_test_num = X_test.select_dtypes(include=['int64', 'float64'])
X_test_num = X_test_num.fillna(0)

# %%
pipeline_path = r"C:\Users\jkk\OneDrive\Desktop\fraud-detection\models\rf_fraud_pipeline.pkl"
rf_pipeline = joblib.load(pipeline_path)

# %%
rf_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['user_id', 'purchase_value', 'age', 'ip_address',
#        'lower_bound_ip_address', 'upper_bound_ip_address', 'time_since_signup',
#        'hour_of_day', 'day_of_week', 'transactions_per_user', 'ip_int'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['signup_time', 'purchase_time', 'device_id', 'source', 'browser', 'sex',
#        'country'],
#       dtype='object'))])),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=10, n_estimators=200,
#                                         n_jobs=-1, random_state=42))])

# %%
rf_model = rf_pipeline.named_steps['classifier']

# %%
import joblib
import pandas as pd

X_test = pd.read_csv(
    r"C:\Users\jkk\OneDrive\Desktop\fraud-detection\data\processed\X_test.csv"
)

rf_pipeline = joblib.load(
    r"C:\Users\jkk\OneDrive\Desktop\fraud-detection\models\rf_fraud_pipeline.pkl"
)

X_test_transformed = rf_pipeline.named_steps['preprocessor'].transform(X_test)

# %%
X_test_sample = X_test.sample(n=500, random_state=42)

# %%
X_test_transformed_sample = rf_pipeline.named_steps['preprocessor'].transform(X_test_sample)

# %%
X_test_transformed_sample = X_test_transformed_sample.toarray()

# %%
explainer = shap.TreeExplainer(rf_model)
shap_values = explainer.shap_values(X_test_transformed_sample)

# %%
import pandas as pd

X_train = pd.read_csv(
    r"C:\Users\jkk\OneDrive\Desktop\fraud-detection\data\processed\X_train.csv"
)

# %%
num_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
cat_cols = X_train.select_dtypes(include=['object']).columns

# %%
onehot_cols = rf_pipeline.named_steps['preprocessor'] \
    .named_transformers_['cat'] \
    .get_feature_names_out(cat_cols)
all_cols = list(num_cols) + list(onehot_cols)

# %%
import shap
import pandas as pd

# Sample 500 rows
X_test_sample = X_test.sample(n=500, random_state=42)

# Transform using pipeline preprocessor
X_test_transformed_sample = rf_pipeline.named_steps['preprocessor'].transform(X_test_sample)

# Convert sparse to dense if necessary
if hasattr(X_test_transformed_sample, "toarray"):
    X_test_transformed_sample = X_test_transformed_sample.toarray()

# Create TreeExplainer for the trained Random Forest
explainer = shap.TreeExplainer(rf_pipeline.named_steps['classifier'])

# Compute SHAP values
shap_values = explainer.shap_values(X_test_transformed_sample)

# Summary plot (global importance)
shap.summary_plot(shap_values[1], X_test_transformed_sample)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 21
#      18 shap_values = explainer.shap_values(X_test_transformed_sample)
#      20 # Summary plot (global importance)
# ---> 21 shap.summary_plot(shap_values[1], X_test_transformed_sample)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\shap\plots\_beeswarm.py:664, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#     659         raise ValueError(
#     660             shape_msg + " Perhaps the extra column in the shap_values matrix is the "
#     661             "constant offset? Of so just pass shap_values[:,:-1]."
#     662         )
#     663     else:
# --> 664         assert num_features == features.shape[1], shape_msg
#     666 if feature_names is None:
#     667     feature_names = np.array([labels["FEATURE"] % str(i) for i in range(num_features)])
#
# AssertionError: The shape of the shap_values matrix does not match the shape of the provided data matrix.
